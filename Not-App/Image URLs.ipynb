# %%
var urllist = []
$("div.image-listing").find("ul").find("li.image-summary").find("div.inner").find("p.asset-name").find("a").each(function () {
    urllist.push($(this).attr("href"));
});
var realurls = []
urllist.forEach(function(item,index) {
    realurls.push("https://www.dermquest.com"+item);})

# %%
import requests

# %%
page = requests.get("https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6700e")

# %%
page.content
# Out:
# b'\n<!DOCTYPE html>\n<html>\n\n\r\n    <head>\r\n        <meta charset="utf-8" />\r\n        <meta http-equiv="Content-type" content="text/html;charset=UTF-8" />\r\n        \r\n    <title>Image Library - basal cell carcinoma </title>\r\n<meta name="description" content="nodular "/>\r\n<meta name="keywords" content="basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma / nodular basal cell carcinoma Plaque / erythematous Squames / scales Trunk / abdomen Asymptomatic "/>\r\n    \r\n\r\n\r\n    \r\n\r\n\r\n        <!-- CSS & JS Library includes -->\r\n        <link rel="SHORTCUT ICON" href="/favicon.ico" />\r\n<!-- CSS -->\r\n<link rel="stylesheet" type="text/css" href="/_themes/default/css/styles.css" media="screen" />\r\n<link rel="stylesheet" type="text/css" href="/_themes/default/css/styles_patch.css" med
# ...

# %%
from bs4 import BeautifulSoup as Soup

# %%
soup = Soup(page.content, 'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
# <title>Image Library - basal cell carcinoma </title>
# <meta content="nodular " name="description"/>
# <meta content="basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma / nodular basal cell carcinoma Plaque / erythematous Squames / scales Trunk / abdomen Asymptomatic " name="keywords"/>
# <!-- CSS & JS Library includes -->
# <link href="/favicon.ico" rel="SHORTCUT ICON"/>
# <!-- CSS -->
# <link href="/_themes/default/css/styles.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="/_themes/default/css/styles_patch.css" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
#   <title>
#    Image Library - basal cell carcinoma
#   </title>
#   <meta content="nodular " name="description"/>
#   <meta content="basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma / nodular basal cell carcinoma Plaque / erythematous Squames / scales Trunk / abdomen Asymptomatic " name="keywords"/>
#   <!-- CSS & JS Library includes -->
#   <link href="/favicon.ico" rel="SHORTCUT ICON"/>
#   <!-- CSS -->
#   <link href="/_themes/default/css/styles.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="/_themes/default/css/styles_patch.css" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
list(soup.children)
# Out:
# ['\n', 'html', '\n', <html>
#  <head>
#  <meta charset="utf-8"/>
#  <meta content="text/html;charset=utf-8" http-equiv="Content-type"/>
#  <title>Image Library - basal cell carcinoma </title>
#  <meta content="nodular " name="description"/>
#  <meta content="basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma tumors and proliferative diseases / epithelial tumors / malignant epithelial tumors / basal cell carcinoma / nodular basal cell carcinoma Plaque / erythematous Squames / scales Trunk / abdomen Asymptomatic " name="keywords"/>
#  <!-- CSS & JS Library includes -->
#  <link href="/favicon.ico" rel="SHORTCUT ICON"/>
#  <!-- CSS -->
#  <link href="/_themes/default/css/styles.css" media="screen" rel="stylesheet" type="text/css"/>
#  <link href="/_themes/default/css/styles_patch.css" media="screen" rel="stylesheet" type="text/css"/>
# ...

# %%
import os

# %%
os.path.split("https://www.dermquest.com/image-library/image/5044bfd1c97267166cd670aa")
# Out:
# ('https://www.dermquest.com/image-library/image', '5044bfd1c97267166cd670aa')

# %%
from bs4 import BeautifulSoup as Soup
page = requests.get("https://www.dermquest.com/image-library/image/5044bfd1c97267166cd670aa")
soup = Soup(page.content, 'html.parser')

# %%
fig = soup.find("li",{"data-image-id":os.path.split("https://www.dermquest.com/image-library/image/5044bfd1c97267166cd670aa")[1]}).find("figure")

# %%
fig
# Out:
# <figure>
# <a class="preview-image" href="/imagelibrary/large/017621HB.JPG" target="_blank"><img alt="basal cell carcinoma" src="/imagelibrary/medium/017621HB.JPG"/></a>
# </figure>

# %%
print(fig.prettify())
# Out:
# <figure>
#  <a class="preview-image" href="/imagelibrary/large/017621HB.JPG" target="_blank">
#   <img alt="basal cell carcinoma" src="/imagelibrary/medium/017621HB.JPG"/>
#  </a>
# </figure>

# %%
fig.find("a")['href']
# Out:
# '/imagelibrary/large/017621HB.JPG'

# %%
# Out:
# NoneType

# %%
[type(item) for item in list(soup.children)]
# Out:
# [bs4.element.Doctype, bs4.element.NavigableString, bs4.element.Tag]

# %%
html = list(soup.children)[2]

# %%
html
# Out:
# <html>
# <head>
# <title>A simple example page</title>
# </head>
# <body>
# <p>Here is some simple content for this page.</p>
# </body>
# </html>

# %%
[item for item in html.children]
# Out:
# ['\n', <head>
#  <title>A simple example page</title>
#  </head>, '\n', <body>
#  <p>Here is some simple content for this page.</p>
#  </body>, '\n']

# %%
body=list(html.children)[3]

# %%
list(body.children)
# Out:
# ['\n', <p>Here is some simple content for this page.</p>, '\n']

# %%
p = list(body.children)[1]

# %%
p
# Out:
# <p>Here is some simple content for this page.</p>

# %%
list(p.children)
# Out:
# ['Here is some simple content for this page.']

# %%
p.get_text()
# Out:
# 'Here is some simple content for this page.'

# %%
soup.find_all('p')
# Out:
# [<p>Here is some simple content for this page.</p>]

# %%
[item.get_text() for item in soup.find_all('p')]
# Out:
# ['Here is some simple content for this page.']

# %%
a = ["https://www.dermquest.com/image-library/image/5044bfd1c97267166cd670ab", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd670aa", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6709a", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd67010", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6700e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd67003", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd67002", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66ff9", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66feb", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fe3", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fd8", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fd2", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fd1", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fd0", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fc2", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fc1", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fb8", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fb5", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66fb0", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e45", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e44", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e3d", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e36", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e26", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e25", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e24", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e1f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e1e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e18", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e17", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e16", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e0f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e0b", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e0a", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e09", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66e01", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66dfc", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66dfb", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66dfa", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66df8", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66df6", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66dea", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66de3", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66de2", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66dde", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c73", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c72", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c71", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c6e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c65", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c64", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c63", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c5e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c5b", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c57", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c56", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c54", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c52", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b87", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b7e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b79", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b76", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b74", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b73", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b6f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b6d", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b6c", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b63", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b5c", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b53", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b51", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b50", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b42", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b41", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b40", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b3f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b3b", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b26", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b25", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b23", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66b1e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66ac6", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd669ce", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd669c8", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd669c1", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd669a9", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6699e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66997", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66992", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66991", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66990", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6698f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6697e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6697d", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6697c", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66977", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6696f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6696e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6681f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6681d"]

# %%
len(a)
# Out:
# 100

# %%
a = a +["https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66816", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66814", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66813", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66812", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66809", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd
"https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61a1a", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61a19", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61a05", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61a00"]

# %%
nevus
# Out:
# ['https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65f4a',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65f49',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65c4c',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65c31',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a9e',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659a9',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6599a',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65987',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd657f7',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65453',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65451',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65419',
# ...

# %%
pyogenic = ["https://www.dermquest.com/image-library/image/5044bfd1c97267166cd67460", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd673c0", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6729e", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66f3f", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66aae", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66469", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65dc9", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65d7b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65d38", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65d37", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65575", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65574", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65573", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65572", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6556d", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65569", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65568", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f3f", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f3e", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f3b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6441f", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64418", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64417", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63df3", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63df2", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63df1", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63df0", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6382b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6382a", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd632be", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd632bd", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd632ba", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd632b8", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd632b6", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd632b5", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62ca5", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62ca4", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62b88", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626fd", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626be", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6260e", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd621ac", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd621ab", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd621a8", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b64", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b61", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61a59"]

# %%
pyogenic
# Out:
# ['https://www.dermquest.com/image-library/image/5044bfd1c97267166cd67460',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd673c0',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6729e',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66f3f',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66aae',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66469',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65dc9',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65d7b',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65d38',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65d37',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65575',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65574',
# ...

# %%
sebor = ["https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66d26", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66d25", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66607", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65b2f", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a3b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a27", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a21", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a1d", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a09", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659d2", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659d1", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659ca", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6555b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd654de", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd650d3", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f29", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f26", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f0d", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64edd", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64eda", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64ec6", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64e25", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64e05", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64ac3", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6490d", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6490c", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64905", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64903", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd648f6", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd648f1", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd648e3", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd648e2", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd648bb", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd648b9", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64699", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64698", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64409", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd643e7", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63dd8", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63d61", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63810", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6380e", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd637a0", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6379f", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6379c", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63795", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63794", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63785", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63784", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6374b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63745", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6371b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63551", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6321a", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c3e", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62bfc", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62b95", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62b8d", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62b8c", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62774", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626df", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6266e", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6266d", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6266c", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62667", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62666", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62661", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62660", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6264f", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62643", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62613", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62612", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd622da", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6219d", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6217c", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6217a", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62177", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b52", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b51", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b4e", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b4c", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b4b", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b0a", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61af2", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61ad0", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61acc", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61acb", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd616e8", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd67081", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66f37", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66f36", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66c03", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66608", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6614a", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66149", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65564", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65563", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f32", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c9d", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c87"]

# %%
sebor = sebor + ["https://www.dermquest.com/image-library/image/5044bfcfc97267166cd6266b", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65538", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6551f", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6551e", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63276", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6325e", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6325d", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64f28", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64eed", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64988", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63d98", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd631d0", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c94", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c1a", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626f3", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626f2", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626ee", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd626ed", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd620c2", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61ae7", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b60", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a07", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a05", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd643d2", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64388", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6326c", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63219", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62649"]

# %%
sebor = sebor + ["https://www.dermquest.com/image-library/image/5044bfd1c97267166cd6679f", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a31", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64922", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64914", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd6437c", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63211", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63210", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b33", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b32", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66d4d", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66a88", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd668ea", "https://www.dermquest.com/image-library/image/5044bfd1c97267166cd662f4", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65f9e", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65f90", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd654df", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd64ee1", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63d95", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62119", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61afb", "https://www.dermquest.com/image-library/image/5044bfd0c97267166cd63dcd", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd61b45", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c53", "https://www.dermquest.com/image-library/image/5044bfcfc97267166cd62c52"]

# %%
len(sebor)
# Out:
# 152

# %%
sebor
# Out:
# ['https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66d26',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66d25',
#  'https://www.dermquest.com/image-library/image/5044bfd1c97267166cd66607',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65b2f',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a3b',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a27',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a21',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a1d',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd65a09',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659d2',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659d1',
#  'https://www.dermquest.com/image-library/image/5044bfd0c97267166cd659ca',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3f786850e387> in <module>()
# ----> 1 a
#
# NameError: name 'a' is not defined
